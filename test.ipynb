# %%
import pandas as pd
from datetime import datetime
# Đọc file Parquet
df = pd.read_parquet('/home/tung/Downloads/DE_K3_M2/project/data/pump/yellow_tripdata_2024-01.parquet', engine='pyarrow')

# Hiển thị dữ liệu
print(df.head())
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
df.columns[[0]]
# Out:
# Index(['VendorID'], dtype='object')

# %%
df.describe()
# Out:
#            VendorID        tpep_pickup_datetime       tpep_dropoff_datetime  \
# count  2.964624e+06                     2964624                     2964624
# mean   1.754204e+00  2024-01-17 00:46:36.431092  2024-01-17 01:02:13.208130
# min    1.000000e+00         2002-12-31 22:59:39         2002-12-31 23:05:41
# 25%    2.000000e+00  2024-01-09 15:59:19.750000         2024-01-09 16:16:23
# 50%    2.000000e+00  2024-01-17 10:45:37.500000  2024-01-17 11:03:51.500000
# 75%    2.000000e+00  2024-01-24 18:23:52.250000         2024-01-24 18:40:29
# max    6.000000e+00         2024-02-01 00:01:15         2024-02-02 13:56:52
# std    4.325902e-01                         NaN                         NaN
#
#        passenger_count  trip_distance    RatecodeID  PULocationID  \
# count     2.824462e+06   2.964624e+06  2.824462e+06  2.964624e+06
# mean      1.339281e+00   3.652169e+00  2.069359e+00  1.660179e+02
# min       0.000000e+00   0.000000e+00  1.000000e+00  1.000000e+00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2964624 entries, 0 to 2964623
# Data columns (total 19 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   VendorID               int32
#  1   tpep_pickup_datetime   datetime64[us]
#  2   tpep_dropoff_datetime  datetime64[us]
#  3   passenger_count        float64
#  4   trip_distance          float64
#  5   RatecodeID             float64
#  6   store_and_fwd_flag     object
#  7   PULocationID           int32
#  8   DOLocationID           int32
#  9   payment_type           int64
#  10  fare_amount            float64
#  11  extra                  float64
#  12  mta_tax                float64
#  13  tip_amount             float64
#  14  tolls_amount           float64
#  15  improvement_surcharge  float64
#  16  total_amount           float64
#  17  congestion_surcharge   float64
#  18  Airport_fee            float64
# dtypes: datetime64[us](2), float64(12), int32(3), int64(1), object(1)
# ...

# %%
row = df.sample()
##convert to list
feature_values = row.values.tolist()[0]

feature_values[1] = str(feature_values[1])
feature_values[2] = str(feature_values[2])
created_time = str(datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
data = [created_time] + feature_values

# %%
import pandas as pd
import os
from datetime import datetime
# Loop through Parquet files in nyc_taxi_data directory
for filename in os.listdir("/home/tung/Downloads/DE_K3_M2/nyc_taxi_data")[2:3]:
    if filename.endswith(".parquet"):
        filepath = os.path.join("/home/tung/Downloads/DE_K3_M2/nyc_taxi_data", filename)

        # Read Parquet data
        data = pd.read_parquet(filepath)
        # print(table)
        # print(data)
        current_datetime = current_datetime = datetime.now()
        data.insert(loc=0, column='created', value=current_datetime)
        print(data)
        print(filename)

# %%
data = data.fillna('NULL')
data
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data = data.fillna('NULL')
#       2 data
#
# AttributeError: 'list' object has no attribute 'fillna'

# %%
data.columns
# Out:
# Index(['created', 'VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'airport_fee'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12442394 entries, 0 to 12442393
# Data columns (total 20 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   created                datetime64[us]
#  1   VendorID               int64
#  2   tpep_pickup_datetime   object
#  3   tpep_dropoff_datetime  object
#  4   passenger_count        int64
#  5   trip_distance          float64
#  6   RatecodeID             int64
#  7   store_and_fwd_flag     object
#  8   PULocationID           int64
#  9   DOLocationID           int64
#  10  payment_type           int64
#  11  fare_amount            float64
#  12  extra                  float64
#  13  mta_tax                float64
#  14  tip_amount             float64
#  15  tolls_amount           float64
#  16  improvement_surcharge  float64
#  17  total_amount           float64
#  18  congestion_surcharge   object
#  19  airport_fee            object
# ...

# %%
len(data.columns)
# Out:
# 20

# %%
import os
os.listdir("/home/tung/Downloads/DE_K3_M2/nyc_taxi_data")
# Out:
# ['yellow_tripdata_2015-02.parquet',
#  'yellow_tripdata_2024-05.parquet',
#  'yellow_tripdata_2020-04.parquet',
#  'green_tripdata_2016-11.parquet',
#  'green_tripdata_2018-04.parquet',
#  'green_tripdata_2021-04.parquet',
#  'yellow_tripdata_2022-04.parquet',
#  'yellow_tripdata_2016-10.parquet',
#  'yellow_tripdata_2017-08.parquet',
#  'yellow_tripdata_2016-12.parquet',
#  'green_tripdata_2017-10.parquet',
#  'green_tripdata_2018-08.parquet',
#  'yellow_tripdata_2022-10.parquet',
#  'green_tripdata_2017-03.parquet',
#  'green_tripdata_2023-06.parquet',
#  'yellow_tripdata_2015-08.parquet',
#  'yellow_tripdata_2017-05.parquet',
#  'green_tripdata_2016-12.parquet',
#  'green_tripdata_2018-09.parquet',
#  'green_tripdata_2017-07.parquet',
#  'yellow_tripdata_2018-01.parquet',
#  'yellow_tripdata_2021-04.parquet',
#  'green_tripdata_2020-01.parquet',
#  'green_tripdata_2020-04.parquet',
#  'green_tripdata_2018-02.parquet',
#  'green_tripdata_2023-01.parquet',
# ...
